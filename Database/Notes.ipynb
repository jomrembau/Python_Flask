# %%
# Set FLASK_APP environment Variable. Run on terminal

set FLASK_APP=myapp.py '

# %%
# flask db init 
flask db init

# %%
Sets up migration File
flask db migrate -m "some message"
# Out:
#   Cell In[5], line 2
#     flask db migrate -m "some message"
#           ^
# SyntaxError: invalid syntax

# %%
Updates Database
flask db upgrade
